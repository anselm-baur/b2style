# %%
# %load_ext autoreload
# %autoreload 2
    
from b2style import B2Figure
import numpy as np

# %%
x = np.linspace(-2, 2, 20)
y = x**2

# %%
b2fig = B2Figure(description={"plot_state": "(Own Work)", "luminosity": 100})
fig, ax = b2fig.create(figsize=[6,5])
ax.plot(x, y)
ax.set_ylabel("2DNLL")
ax.set_xlabel("lifetime shift in fs")
fig.savefig("test_fig.pdf")
# Out:
# plot_state (Own Work)
# plot_state (Own Work)
#
# [ 75. 422.]

# %% [markdown]
# #
